# %% [markdown]
# # Chinook Sample DB - SQLite

# %%
import sqlite3
import pandas as pd
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

db = 'chinook.db'

# Create function to return pd.Dataframe from SQL query string

def run_query(q):
    with sqlite3.connect(db) as conn:
        return pd.read_sql(q, conn)

# List all tables and views in the DB

tables = run_query('''
    SELECT
        name,
        type
    FROM sqlite_master
    WHERE type IN ("table","view");
               ''')

tables
# Out:
#                name   type
# 0            albums  table
# 1   sqlite_sequence  table
# 2           artists  table
# 3         customers  table
# 4         employees  table
# 5            genres  table
# 6          invoices  table
# 7     invoice_items  table
# 8       media_types  table
# 9         playlists  table
# 10   playlist_track  table
# 11           tracks  table
# 12     sqlite_stat1  table

# %%
# Top 25 Selling Audio Tracks by Revenue

top_tracks = '''
SELECT t.name track_name,
       ar.name artist_name,
       SUM(ii.unitPrice * ii.quantity) total_revenue
FROM artists ar
JOIN albums al ON al.artistId = ar.artistId
JOIN tracks t ON t.albumId = al.albumId
JOIN invoice_items ii ON ii.trackId = t.trackId
JOIN media_types mt ON mt.mediaTypeId = t.mediaTypeId
WHERE mt.name IN (SELECT DISTINCT name
                  FROM media_types
                  WHERE name LIKE "%audio%")
GROUP BY 1,2
ORDER BY 3 DESC
LIMIT 25;
'''
run_query(top_tracks)
# Out:
#                    track_name              artist_name  total_revenue
# 0                 The Trooper              Iron Maiden           4.95
# 1                    Eruption                Van Halen           3.96
# 2        Hallowed Be Thy Name              Iron Maiden           3.96
# 3         Sure Know Something                     Kiss           3.96
# 4     The Number Of The Beast              Iron Maiden           3.96
# 5       2 Minutes To Midnight              Iron Maiden           2.97
# 6              Blood Brothers              Iron Maiden           2.97
# 7     Can I Play With Madness              Iron Maiden           2.97
# 8          Dazed and Confused             Led Zeppelin           2.97
# 9           Flying High Again            Ozzy Osbourne           2.97
# 10            Heaven Can Wait              Iron Maiden           2.97
# 11             Plaster Caster                     Kiss           2.97
# 12                    Release            The Tea Party           2.97
# 13                   Selvagem  Os Paralamas Do Sucesso           2.97
# 14         Stairway To Heaven             Led Zeppelin           2.97
# 15             Sweetest Thing                       U2           2.97
# 16          Where Eagles Dare              Iron Maiden           2.97
# 17               A Cor Do Sol             Cidade Negra           1.98
# 18             A Melhor Forma                    Titãs           1.98
# 19          A Novidade (Live)             Gilberto Gil           1.98
# 20   Abraham, Martin And John              Marvin Gaye           1.98
# 21                   Acelerou                   Djavan           1.98
# 22                  Aces High              Iron Maiden           1.98
# 23  Afraid To Shoot Strangers              Iron Maiden           1.98
# 24   All Along The Watchtower                       U2           1.98

# %%
# Top 20 Selling Albums by number of tracks sold

top_albums = '''
WITH ta AS (SELECT t.trackId,
                   al.title album_title,
                   ar.name artist_name,
                   mt.name media_type
            FROM tracks t
            JOIN media_types mt ON mt.mediaTypeID = t.mediaTypeID
            JOIN albums al ON al.albumId = t.albumId
            JOIN artists ar ON ar.artistId = al.artistId
            ),
      
      mt AS (SELECT DISTINCT name
             FROM media_types
             WHERE name LIKE "%audio%")

SELECT
    ta.album_title album,
    ta.artist_name artist,
    ta.media_type media_type,
    SUM(ii.quantity) tracks_purchased
FROM invoice_items ii
JOIN ta
ON ta.trackId = ii.trackId
WHERE ta.media_type IN mt
GROUP BY 1, 2, 3
ORDER BY 4 DESC 
LIMIT 20;
'''

run_query(top_albums)
# Out:
#                                                 album  \
# 0                                      Minha Historia
# 1                                       Greatest Hits
# 2                                           Unplugged
# 3                                            Acústico
# 4                                       Greatest Kiss
# 5                                   Chronicle, Vol. 2
# 6            My Generation - The Very Best Of The Who
# 7                                        Prenda Minha
# 8                                        Acústico MTV
# 9                                   Chronicle, Vol. 1
# 10                            International Superhits
# 11                                     Rattle And Hum
# 12                  The Best Of R.E.M.: The IRS Years
# 13                                        Up An' Atom
# 14                                Use Your Illusion I
# 15                                     Afrociberdelia
# 16  Instant Karma: The Amnesty International Campa...
# 17                                            A-Sides
# 18                                     American Idiot
# 19                    Arquivo Os Paralamas Do Sucesso
#
#                           artist                media_type  tracks_purchased
# 0                  Chico Buarque           MPEG audio file                27
# 1                  Lenny Kravitz           MPEG audio file                26
# 2                   Eric Clapton           MPEG audio file                25
# 3                          Titãs           MPEG audio file                22
# 4                           Kiss           MPEG audio file                20
# 5   Creedence Clearwater Revival           MPEG audio file                19
# 6                        The Who           MPEG audio file                19
# 7                 Caetano Veloso           MPEG audio file                19
# 8        Os Paralamas Do Sucesso           MPEG audio file                18
# 9   Creedence Clearwater Revival           MPEG audio file                18
# 10                     Green Day           MPEG audio file                18
# 11                            U2           MPEG audio file                17
# 12                        R.E.M.           MPEG audio file                17
# 13                    Gene Krupa           MPEG audio file                17
# 14                 Guns N' Roses  Protected AAC audio file                17
# 15   Chico Science & Nação Zumbi           MPEG audio file                16
# 16                            U2  Protected AAC audio file                16
# 17                   Soundgarden           MPEG audio file                15
# 18                     Green Day           MPEG audio file                15
# 19       Os Paralamas Do Sucesso           MPEG audio file                15

# %%
# Create Day column and plot histogram of invoice frequency by day of month
tmp = run_query('SELECT * FROM invoices')

def get_day(row):
    dtime = datetime.datetime.strptime(row, '%Y-%m-%d %X')
    return dtime.day

tmp['day'] = tmp['InvoiceDate'].apply(get_day)
tmp['day'].hist(bins = 31)

# %%
# List of customers, their last purchase, and the total for the purchase

last_order = '''
WITH ci AS (SELECT c.customerId, 
            c.firstname || " " || c.lastname customer_name,
            MAX(invoicedate) last_order
            FROM customers c
            LEFT JOIN invoices i ON i.customerid = c.customerid
            GROUP BY 1)

SELECT ci.customer_name,
       ci.last_order,
       i.total
FROM invoices i
JOIN ci ON i.customerId = ci.customerId
AND i.invoiceDate = ci.last_order
ORDER BY 3 DESC
'''
run_query(last_order)
# Out:
#             customer_name           last_order  Total
# 0             Helena Holý  2013-11-13 00:00:00  25.86
# 1         Eduardo Martins  2013-08-12 00:00:00  13.86
# 2            Mark Philips  2013-05-11 00:00:00  13.86
# 3            Patrick Gray  2013-10-13 00:00:00  13.86
# 4             Martha Silk  2013-07-12 00:00:00  13.86
# 5        Terhi Hämäläinen  2013-12-14 00:00:00  13.86
# 6   Johannes Van der Berg  2013-09-12 00:00:00  13.86
# 7              Emma Jones  2013-06-11 00:00:00  13.86
# 8              Jack Smith  2012-07-31 00:00:00  10.91
# 9          João Fernandes  2012-10-01 00:00:00  10.91
# 10         Luís Gonçalves  2013-08-07 00:00:00   8.91
# 11  František Wichterlová  2013-05-06 00:00:00   8.91
# 12           Kara Nielsen  2013-02-02 00:00:00   8.91
# 13         Fernanda Ramos  2012-11-01 00:00:00   8.91
# 14        Michelle Brooks  2013-10-08 00:00:00   8.91
# 15        Heather Leacock  2013-07-07 00:00:00   8.91
# 16     Richard Cunningham  2013-04-05 00:00:00   8.91
# 17         Edward Francis  2013-01-02 00:00:00   8.91
# 18       Madalena Sampaio  2013-12-09 00:00:00   8.91
# 19        Niklas Schröder  2012-06-30 00:00:00   8.91
# 20        Camille Bernard  2013-09-07 00:00:00   8.91
# 21       Isabelle Mercier  2013-06-06 00:00:00   8.91
# 22          Lucas Mancini  2013-03-05 00:00:00   8.91
# 23       Joakim Johansson  2012-12-02 00:00:00   8.91
# 24            Mark Taylor  2012-08-31 00:00:00   8.91
# 25        Diego Gutiérrez  2013-11-08 00:00:00   8.91
# 26        Puja Srivastava  2012-05-30 00:00:00   8.91
# 27        Roberto Almeida  2013-10-05 00:00:00   5.94
# 28           Frank Harris  2013-07-04 00:00:00   5.94
# 29           Robert Brown  2013-12-06 00:00:00   5.94
# 30         Ellie Sullivan  2013-09-04 00:00:00   5.94
# 31        Fynn Zimmermann  2013-06-03 00:00:00   5.94
# 32          Enrique Muñoz  2013-11-05 00:00:00   5.94
# 33           Steve Murray  2013-08-04 00:00:00   5.94
# 34           Daan Peeters  2013-10-04 00:00:00   3.96
# 35         Victor Stevens  2013-12-05 00:00:00   3.96
# 36          Hugh O'Reilly  2013-11-04 00:00:00   3.96
# 37              Tim Goyer  2012-09-13 00:00:00   1.99
# 38           Manoj Pareek  2013-12-22 00:00:00   1.99
# 39           Bjørn Hansen  2013-10-03 00:00:00   1.98
# 40            Kathy Chase  2013-12-04 00:00:00   1.98
# 41            John Gordon  2013-12-04 00:00:00   1.98
# 42           Wyatt Girard  2013-11-03 00:00:00   1.98
# 43          Leonie Köhler  2012-07-13 00:00:00   0.99
# 44      François Tremblay  2013-09-20 00:00:00   0.99
# 45          Astrid Gruber  2013-06-19 00:00:00   0.99
# 46        Alexandre Rocha  2013-03-18 00:00:00   0.99
# 47      Jennifer Peterson  2012-12-15 00:00:00   0.99
# 48             Dan Miller  2013-11-21 00:00:00   0.99
# 49          Frank Ralston  2013-08-20 00:00:00   0.99
# 50          Julia Barnett  2013-05-19 00:00:00   0.99
# 51         Aaron Mitchell  2013-02-15 00:00:00   0.99
# 52       Hannah Schneider  2012-11-14 00:00:00   0.99
# 53     Dominique Lefebvre  2012-08-13 00:00:00   0.99
# 54            Marc Dubois  2013-10-21 00:00:00   0.99
# 55        Ladislav Kovács  2013-07-20 00:00:00   0.99
# 56       Stanisław Wójcik  2013-04-18 00:00:00   0.99
# 57            Phil Hughes  2013-01-15 00:00:00   0.99
# 58             Luis Rojas  2012-10-14 00:00:00   0.99

# %%
# All orders for CustomerID 40
invoice_rank = '''
SELECT c.customerId,
       i.invoiceId,
       i.invoiceDate,
       i.total
FROM customers c
JOIN invoices i ON i.customerId = c.customerId
WHERE c.customerId = 40
ORDER BY 4 DESC
'''

run_query(invoice_rank)
# Out:
#    CustomerId  InvoiceId          InvoiceDate  Total
# 0          40         19  2009-03-14 00:00:00  13.86
# 1          40         74  2009-11-12 00:00:00   8.91
# 2          40        248  2011-12-24 00:00:00   5.94
# 3          40        226  2011-09-21 00:00:00   3.96
# 4          40        203  2011-06-19 00:00:00   2.98
# 5          40          8  2009-02-01 00:00:00   1.98
# 6          40        300  2012-08-13 00:00:00   0.99
